# %%
import numpy as np
import os
import random
import tensorflow as tf

from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from tensorflow import keras
from tensorflow.keras import layers
from utils import *

# %matplotlib inline
# Out:
# 2023-07-17 15:29:39.552258: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-17 15:29:40.547228: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
os.environ["PYTHONHASHSEED"] = "0"
random.seed(1234)
np.random.seed(1234)
tf.random.set_seed(1234)

# %%
folder_path = './dataset1_3objects'

x, y = read_dataset1(folder_path)

# %%
draw_bar_chart(y)

print(np.unique(y))

n_classes = len(np.unique(y))

print(n_classes)
# Out:
# [0 1 2]
# 3

# %%
# shuffle
x, y = shuffle(x, y, random_state=0)

# split
x_temp, x_test, y_temp, y_test = train_test_split(x, y, test_size=1/5, random_state=0, stratify=y)

x_train, x_val, y_train, y_val = train_test_split(x_temp, y_temp, test_size=1/4, random_state=0, stratify=y_temp)

# %%
draw_bar_chart(y_val)
draw_bar_chart(y_test)

# %%
def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0):
    # Normalization and Attention
    x = layers.LayerNormalization(epsilon=1e-6)(inputs)
    x = layers.MultiHeadAttention(
        key_dim=head_size, num_heads=num_heads, dropout=dropout
    )(x, x)
    x = layers.Dropout(dropout)(x)
    res = x + inputs

    # Feed Forward Part
    x = layers.LayerNormalization(epsilon=1e-6)(res)
    x = layers.Conv1D(filters=ff_dim, kernel_size=1, activation="relu")(x)
    x = layers.Dropout(dropout)(x)
    x = layers.Conv1D(filters=inputs.shape[-1], kernel_size=1)(x)
    return x + res

# %%
def build_model(
    input_shape,
    head_size,
    num_heads,
    ff_dim,
    num_transformer_blocks,
    mlp_units,
    dropout=0,
    mlp_dropout=0,
):
    inputs = keras.Input(shape=input_shape)
    x = inputs
    for _ in range(num_transformer_blocks):
        x = transformer_encoder(x, head_size, num_heads, ff_dim, dropout)

    x = layers.GlobalAveragePooling1D(data_format="channels_first")(x)
    for dim in mlp_units:
        x = layers.Dense(dim, activation="relu")(x)
        x = layers.Dropout(mlp_dropout)(x)
    outputs = layers.Dense(n_classes, activation="softmax")(x)
    return keras.Model(inputs, outputs)

# %%
input_shape = x.shape[1:]

model = build_model(
    input_shape,
    head_size=256,
    num_heads=4,
    ff_dim=4,
    num_transformer_blocks=4,
    mlp_units=[128],
    mlp_dropout=0.4,
    dropout=0.25,
)

model.compile(
    loss="sparse_categorical_crossentropy",
    optimizer=keras.optimizers.Adam(learning_rate=1e-3),
    metrics=["sparse_categorical_accuracy"]
)
model.summary()

callbacks = [
    keras.callbacks.EarlyStopping(patience=200, restore_best_weights=True),
    keras.callbacks.ModelCheckpoint("./dataset1_transformer_results/transformer_model.h5",
        monitor='val_loss',  # Optional: Monitor a specific metric to save the best weights
        save_weights_only=False,  # Save the entire model
        save_best_only=True,  # Save only the best weights based on the monitored metric
        verbose=1  # Optional: Display messages when saving weights
    )
]

results = model.fit(
    x_train,
    y_train,
    validation_data=(x_val,y_val),
    epochs=10000,
    batch_size=64,
    callbacks=callbacks,
)

l, a = model.evaluate(x_val, y_val, verbose=1)

print(l, a)

L, A = model.evaluate(x_test, y_test, verbose=1)

print(L, A)
# Out:
# 2023-07-17 15:29:44.128154: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-17 15:29:44.166731: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-17 15:29:44.167003: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-17 15:29:44.168012: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-17 15:29:44.168263: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-17 15:29:44.168481: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-17 15:29:44.962429: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-17 15:29:44.962739: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-17 15:29:44.963250: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-17 15:29:44.963433: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2853 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 960M, pci bus id: 0000:01:00.0, compute capability: 5.0
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 21, 3)]      0           []
#
#  layer_normalization (LayerNorm  (None, 21, 3)       6           ['input_1[0][0]']
#  alization)
#
#  multi_head_attention (MultiHea  (None, 21, 3)       15363       ['layer_normalization[0][0]',
#  dAttention)                                                      'layer_normalization[0][0]']
#
#  dropout (Dropout)              (None, 21, 3)        0           ['multi_head_attention[0][0]']
#
#  tf.__operators__.add (TFOpLamb  (None, 21, 3)       0           ['dropout[0][0]',
#  da)                                                              'input_1[0][0]']
#
#  layer_normalization_1 (LayerNo  (None, 21, 3)       6           ['tf.__operators__.add[0][0]']
#  rmalization)
#
#  conv1d (Conv1D)                (None, 21, 4)        16          ['layer_normalization_1[0][0]']
#
#  dropout_1 (Dropout)            (None, 21, 4)        0           ['conv1d[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 21, 3)        15          ['dropout_1[0][0]']
#
#  tf.__operators__.add_1 (TFOpLa  (None, 21, 3)       0           ['conv1d_1[0][0]',
#  mbda)                                                            'tf.__operators__.add[0][0]']
#
#  layer_normalization_2 (LayerNo  (None, 21, 3)       6           ['tf.__operators__.add_1[0][0]']
#  rmalization)
#
#  multi_head_attention_1 (MultiH  (None, 21, 3)       15363       ['layer_normalization_2[0][0]',
#  eadAttention)                                                    'layer_normalization_2[0][0]']
#
#  dropout_2 (Dropout)            (None, 21, 3)        0           ['multi_head_attention_1[0][0]']
#
#  tf.__operators__.add_2 (TFOpLa  (None, 21, 3)       0           ['dropout_2[0][0]',
#  mbda)                                                            'tf.__operators__.add_1[0][0]']
#
#  layer_normalization_3 (LayerNo  (None, 21, 3)       6           ['tf.__operators__.add_2[0][0]']
#  rmalization)
#
#  conv1d_2 (Conv1D)              (None, 21, 4)        16          ['layer_normalization_3[0][0]']
#
#  dropout_3 (Dropout)            (None, 21, 4)        0           ['conv1d_2[0][0]']
#
#  conv1d_3 (Conv1D)              (None, 21, 3)        15          ['dropout_3[0][0]']
#
#  tf.__operators__.add_3 (TFOpLa  (None, 21, 3)       0           ['conv1d_3[0][0]',
#  mbda)                                                            'tf.__operators__.add_2[0][0]']
#
#  layer_normalization_4 (LayerNo  (None, 21, 3)       6           ['tf.__operators__.add_3[0][0]']
#  rmalization)
#
#  multi_head_attention_2 (MultiH  (None, 21, 3)       15363       ['layer_normalization_4[0][0]',
#  eadAttention)                                                    'layer_normalization_4[0][0]']
#
#  dropout_4 (Dropout)            (None, 21, 3)        0           ['multi_head_attention_2[0][0]']
#
#  tf.__operators__.add_4 (TFOpLa  (None, 21, 3)       0           ['dropout_4[0][0]',
#  mbda)                                                            'tf.__operators__.add_3[0][0]']
#
#  layer_normalization_5 (LayerNo  (None, 21, 3)       6           ['tf.__operators__.add_4[0][0]']
#  rmalization)
#
#  conv1d_4 (Conv1D)              (None, 21, 4)        16          ['layer_normalization_5[0][0]']
#
#  dropout_5 (Dropout)            (None, 21, 4)        0           ['conv1d_4[0][0]']
#
#  conv1d_5 (Conv1D)              (None, 21, 3)        15          ['dropout_5[0][0]']
#
#  tf.__operators__.add_5 (TFOpLa  (None, 21, 3)       0           ['conv1d_5[0][0]',
#  mbda)                                                            'tf.__operators__.add_4[0][0]']
#
#  layer_normalization_6 (LayerNo  (None, 21, 3)       6           ['tf.__operators__.add_5[0][0]']
#  rmalization)
#
#  multi_head_attention_3 (MultiH  (None, 21, 3)       15363       ['layer_normalization_6[0][0]',
#  eadAttention)                                                    'layer_normalization_6[0][0]']
#
#  dropout_6 (Dropout)            (None, 21, 3)        0           ['multi_head_attention_3[0][0]']
#
#  tf.__operators__.add_6 (TFOpLa  (None, 21, 3)       0           ['dropout_6[0][0]',
#  mbda)                                                            'tf.__operators__.add_5[0][0]']
#
#  layer_normalization_7 (LayerNo  (None, 21, 3)       6           ['tf.__operators__.add_6[0][0]']
#  rmalization)
#
#  conv1d_6 (Conv1D)              (None, 21, 4)        16          ['layer_normalization_7[0][0]']
#
#  dropout_7 (Dropout)            (None, 21, 4)        0           ['conv1d_6[0][0]']
#
#  conv1d_7 (Conv1D)              (None, 21, 3)        15          ['dropout_7[0][0]']
#
#  tf.__operators__.add_7 (TFOpLa  (None, 21, 3)       0           ['conv1d_7[0][0]',
#  mbda)                                                            'tf.__operators__.add_6[0][0]']
#
#  global_average_pooling1d (Glob  (None, 21)          0           ['tf.__operators__.add_7[0][0]']
#  alAveragePooling1D)
#
#  dense (Dense)                  (None, 128)          2816        ['global_average_pooling1d[0][0]'
#                                                                  ]
#
#  dropout_8 (Dropout)            (None, 128)          0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 3)            387         ['dropout_8[0][0]']
#
# ==================================================================================================
# Total params: 64,827
# Trainable params: 64,827
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/10000
# 2023-07-17 15:29:52.330927: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8900
# 2023-07-17 15:29:52.962237: I tensorflow/compiler/xla/service/service.cc:169] XLA service 0x7fae415e8c00 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-07-17 15:29:52.962261: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (0): NVIDIA GeForce GTX 960M, Compute Capability 5.0
# 2023-07-17 15:29:52.967479: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-07-17 15:29:53.102367: I ./tensorflow/compiler/jit/device_compiler.h:180] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 9/9 [==============================] - ETA: 0s - loss: 1.1793 - sparse_categorical_accuracy: 0.3277
# Epoch 1: val_loss improved from inf to 1.10126, saving model to ./dataset1_transformer_results/transformer_model
# 9/9 [==============================] - 16s 193ms/step - loss: 1.1793 - sparse_categorical_accuracy: 0.3277 - val_loss: 1.1013 - val_sparse_categorical_accuracy: 0.3202
# Epoch 2/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 1.1788 - sparse_categorical_accuracy: 0.3184
# Epoch 2: val_loss improved from 1.10126 to 1.06914, saving model to ./dataset1_transformer_results/transformer_model
# 9/9 [==============================] - 1s 110ms/step - loss: 1.1853 - sparse_categorical_accuracy: 0.3146 - val_loss: 1.0691 - val_sparse_categorical_accuracy: 0.5562
# Epoch 3/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 1.1561 - sparse_categorical_accuracy: 0.3633
# Epoch 3: val_loss did not improve from 1.06914
# 9/9 [==============================] - 1s 65ms/step - loss: 1.1574 - sparse_categorical_accuracy: 0.3596 - val_loss: 1.1074 - val_sparse_categorical_accuracy: 0.3989
# Epoch 4/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 1.1141 - sparse_categorical_accuracy: 0.3770
# Epoch 4: val_loss improved from 1.06914 to 1.03248, saving model to ./dataset1_transformer_results/transformer_model
# 9/9 [==============================] - 1s 90ms/step - loss: 1.1221 - sparse_categorical_accuracy: 0.3689 - val_loss: 1.0325 - val_sparse_categorical_accuracy: 0.5955
# Epoch 5/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 1.1283 - sparse_categorical_accuracy: 0.3730
# Epoch 5: val_loss improved from 1.03248 to 1.01886, saving model to ./dataset1_transformer_results/transformer_model
# 9/9 [==============================] - 1s 95ms/step - loss: 1.1264 - sparse_categorical_accuracy: 0.3708 - val_loss: 1.0189 - val_sparse_categorical_accuracy: 0.6404
# Epoch 6/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 1.1473 - sparse_categorical_accuracy: 0.3672
# Epoch 6: val_loss improved from 1.01886 to 1.00757, saving model to ./dataset1_transformer_results/transformer_model
# 9/9 [==============================] - 1s 92ms/step - loss: 1.1435 - sparse_categorical_accuracy: 0.3745 - val_loss: 1.0076 - val_sparse_categorical_accuracy: 0.7079
# Epoch 7/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 1.0929 - sparse_categorical_accuracy: 0.4082
# Epoch 7: val_loss improved from 1.00757 to 0.99188, saving model to ./dataset1_transformer_results/transformer_model
# 9/9 [==============================] - 1s 90ms/step - loss: 1.0917 - sparse_categorical_accuracy: 0.4120 - val_loss: 0.9919 - val_sparse_categorical_accuracy: 0.7247
# Epoch 8/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 1.0691 - sparse_categorical_accuracy: 0.4316
# Epoch 8: val_loss improved from 0.99188 to 0.97861, saving model to ./dataset1_transformer_results/transformer_model
# 9/9 [==============================] - 1s 89ms/step - loss: 1.0700 - sparse_categorical_accuracy: 0.4288 - val_loss: 0.9786 - val_sparse_categorical_accuracy: 0.6798
# Epoch 9/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 1.0355 - sparse_categorical_accuracy: 0.4590
# Epoch 9: val_loss improved from 0.97861 to 0.94093, saving model to ./dataset1_transformer_results/transformer_model
# 9/9 [==============================] - 1s 89ms/step - loss: 1.0341 - sparse_categorical_accuracy: 0.4588 - val_loss: 0.9409 - val_sparse_categorical_accuracy: 0.6685
# Epoch 10/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 1.0372 - sparse_categorical_accuracy: 0.4609
# Epoch 10: val_loss improved from 0.94093 to 0.87437, saving model to ./dataset1_transformer_results/transformer_model
# 9/9 [==============================] - 1s 119ms/step - loss: 1.0354 - sparse_categorical_accuracy: 0.4625 - val_loss: 0.8744 - val_sparse_categorical_accuracy: 0.6966
# Epoch 11/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.9758 - sparse_categorical_accuracy: 0.4863
# Epoch 11: val_loss did not improve from 0.87437
# 9/9 [==============================] - 1s 63ms/step - loss: 0.9688 - sparse_categorical_accuracy: 0.4925 - val_loss: 0.8953 - val_sparse_categorical_accuracy: 0.6404
# Epoch 12/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.9434 - sparse_categorical_accuracy: 0.5684
# Epoch 12: val_loss improved from 0.87437 to 0.82025, saving model to ./dataset1_transformer_results/transformer_model
# 9/9 [==============================] - 1s 85ms/step - loss: 0.9392 - sparse_categorical_accuracy: 0.5693 - val_loss: 0.8203 - val_sparse_categorical_accuracy: 0.6573
# Epoch 13/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.8785 - sparse_categorical_accuracy: 0.5898
# Epoch 13: val_loss improved from 0.82025 to 0.73818, saving model to ./dataset1_transformer_results/transformer_model
# 9/9 [==============================] - 1s 95ms/step - loss: 0.8827 - sparse_categorical_accuracy: 0.5824 - val_loss: 0.7382 - val_sparse_categorical_accuracy: 0.6966
# Epoch 14/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.8203 - sparse_categorical_accuracy: 0.6328
# Epoch 14: val_loss improved from 0.73818 to 0.65475, saving model to ./dataset1_transformer_results/transformer_model
# 9/9 [==============================] - 1s 91ms/step - loss: 0.8198 - sparse_categorical_accuracy: 0.6311 - val_loss: 0.6548 - val_sparse_categorical_accuracy: 0.7079
# Epoch 15/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.7536 - sparse_categorical_accuracy: 0.6367
# Epoch 15: val_loss improved from 0.65475 to 0.60050, saving model to ./dataset1_transformer_results/transformer_model
# 9/9 [==============================] - 1s 90ms/step - loss: 0.7490 - sparse_categorical_accuracy: 0.6386 - val_loss: 0.6005 - val_sparse_categorical_accuracy: 0.7472
# Epoch 16/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.7236 - sparse_categorical_accuracy: 0.6523
# Epoch 16: val_loss did not improve from 0.60050
# 9/9 [==============================] - 1s 64ms/step - loss: 0.7211 - sparse_categorical_accuracy: 0.6517 - val_loss: 0.6260 - val_sparse_categorical_accuracy: 0.6742
# Epoch 17/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.6645 - sparse_categorical_accuracy: 0.6875
# Epoch 17: val_loss improved from 0.60050 to 0.55510, saving model to ./dataset1_transformer_results/transformer_model
# 9/9 [==============================] - 1s 100ms/step - loss: 0.6667 - sparse_categorical_accuracy: 0.6835 - val_loss: 0.5551 - val_sparse_categorical_accuracy: 0.7360
# Epoch 18/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.6096 - sparse_categorical_accuracy: 0.7070
# Epoch 18: val_loss improved from 0.55510 to 0.54168, saving model to ./dataset1_transformer_results/transformer_model
# 9/9 [==============================] - 1s 95ms/step - loss: 0.6025 - sparse_categorical_accuracy: 0.7060 - val_loss: 0.5417 - val_sparse_categorical_accuracy: 0.7303
# Epoch 19/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.5810 - sparse_categorical_accuracy: 0.7227
# Epoch 19: val_loss improved from 0.54168 to 0.52840, saving model to ./dataset1_transformer_results/transformer_model
# 9/9 [==============================] - 1s 95ms/step - loss: 0.5802 - sparse_categorical_accuracy: 0.7247 - val_loss: 0.5284 - val_sparse_categorical_accuracy: 0.7247
# Epoch 20/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.5260 - sparse_categorical_accuracy: 0.7637
# Epoch 20: val_loss did not improve from 0.52840
# 9/9 [==============================] - 1s 65ms/step - loss: 0.5196 - sparse_categorical_accuracy: 0.7678 - val_loss: 0.5365 - val_sparse_categorical_accuracy: 0.7247
# Epoch 21/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.5320 - sparse_categorical_accuracy: 0.7520
# Epoch 21: val_loss improved from 0.52840 to 0.48011, saving model to ./dataset1_transformer_results/transformer_model
# 9/9 [==============================] - 1s 107ms/step - loss: 0.5425 - sparse_categorical_accuracy: 0.7453 - val_loss: 0.4801 - val_sparse_categorical_accuracy: 0.7978
# Epoch 22/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.5378 - sparse_categorical_accuracy: 0.7324
# Epoch 22: val_loss did not improve from 0.48011
# 9/9 [==============================] - 1s 66ms/step - loss: 0.5438 - sparse_categorical_accuracy: 0.7360 - val_loss: 0.5370 - val_sparse_categorical_accuracy: 0.7416
# Epoch 23/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.5348 - sparse_categorical_accuracy: 0.7559
# Epoch 23: val_loss improved from 0.48011 to 0.42457, saving model to ./dataset1_transformer_results/transformer_model
# 9/9 [==============================] - 1s 90ms/step - loss: 0.5328 - sparse_categorical_accuracy: 0.7547 - val_loss: 0.4246 - val_sparse_categorical_accuracy: 0.8258
# Epoch 24/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.4982 - sparse_categorical_accuracy: 0.7539
# Epoch 24: val_loss did not improve from 0.42457
# 9/9 [==============================] - 1s 62ms/step - loss: 0.4998 - sparse_categorical_accuracy: 0.7566 - val_loss: 0.4371 - val_sparse_categorical_accuracy: 0.8146
# Epoch 25/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.4942 - sparse_categorical_accuracy: 0.7676
# Epoch 25: val_loss improved from 0.42457 to 0.41633, saving model to ./dataset1_transformer_results/transformer_model
# 9/9 [==============================] - 1s 84ms/step - loss: 0.4951 - sparse_categorical_accuracy: 0.7659 - val_loss: 0.4163 - val_sparse_categorical_accuracy: 0.8483
# Epoch 26/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.5075 - sparse_categorical_accuracy: 0.7598
# Epoch 26: val_loss improved from 0.41633 to 0.39474, saving model to ./dataset1_transformer_results/transformer_model
# 9/9 [==============================] - 1s 90ms/step - loss: 0.5006 - sparse_categorical_accuracy: 0.7640 - val_loss: 0.3947 - val_sparse_categorical_accuracy: 0.8371
# Epoch 27/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.4675 - sparse_categorical_accuracy: 0.7539
# Epoch 27: val_loss did not improve from 0.39474
# 9/9 [==============================] - 1s 60ms/step - loss: 0.4654 - sparse_categorical_accuracy: 0.7528 - val_loss: 0.4081 - val_sparse_categorical_accuracy: 0.7697
# Epoch 28/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.4472 - sparse_categorical_accuracy: 0.8008
# Epoch 28: val_loss improved from 0.39474 to 0.38187, saving model to ./dataset1_transformer_results/transformer_model
# 9/9 [==============================] - 1s 92ms/step - loss: 0.4437 - sparse_categorical_accuracy: 0.8034 - val_loss: 0.3819 - val_sparse_categorical_accuracy: 0.8258
# Epoch 29/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.4724 - sparse_categorical_accuracy: 0.7793
# Epoch 29: val_loss did not improve from 0.38187
# 9/9 [==============================] - 1s 64ms/step - loss: 0.4678 - sparse_categorical_accuracy: 0.7809 - val_loss: 0.4076 - val_sparse_categorical_accuracy: 0.8202
# Epoch 30/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.4564 - sparse_categorical_accuracy: 0.7832
# Epoch 30: val_loss did not improve from 0.38187
# 9/9 [==============================] - 1s 64ms/step - loss: 0.4586 - sparse_categorical_accuracy: 0.7828 - val_loss: 0.3841 - val_sparse_categorical_accuracy: 0.8202
# Epoch 31/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.4219 - sparse_categorical_accuracy: 0.7852
# Epoch 31: val_loss improved from 0.38187 to 0.37811, saving model to ./dataset1_transformer_results/transformer_model
# 9/9 [==============================] - 1s 86ms/step - loss: 0.4208 - sparse_categorical_accuracy: 0.7903 - val_loss: 0.3781 - val_sparse_categorical_accuracy: 0.8315
# Epoch 32/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.4422 - sparse_categorical_accuracy: 0.7832
# Epoch 32: val_loss did not improve from 0.37811
# 9/9 [==============================] - 1s 62ms/step - loss: 0.4462 - sparse_categorical_accuracy: 0.7790 - val_loss: 0.3956 - val_sparse_categorical_accuracy: 0.8258
# Epoch 33/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.4020 - sparse_categorical_accuracy: 0.8262
# Epoch 33: val_loss did not improve from 0.37811
# 9/9 [==============================] - 1s 64ms/step - loss: 0.4102 - sparse_categorical_accuracy: 0.8240 - val_loss: 0.3808 - val_sparse_categorical_accuracy: 0.8596
# Epoch 34/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.3964 - sparse_categorical_accuracy: 0.8184
# Epoch 34: val_loss improved from 0.37811 to 0.37773, saving model to ./dataset1_transformer_results/transformer_model
# 9/9 [==============================] - 1s 88ms/step - loss: 0.3956 - sparse_categorical_accuracy: 0.8202 - val_loss: 0.3777 - val_sparse_categorical_accuracy: 0.8652
# Epoch 35/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.4252 - sparse_categorical_accuracy: 0.8047
# Epoch 35: val_loss improved from 0.37773 to 0.37079, saving model to ./dataset1_transformer_results/transformer_model
# 9/9 [==============================] - 1s 85ms/step - loss: 0.4214 - sparse_categorical_accuracy: 0.8071 - val_loss: 0.3708 - val_sparse_categorical_accuracy: 0.8539
# Epoch 36/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.3970 - sparse_categorical_accuracy: 0.8184
# Epoch 36: val_loss improved from 0.37079 to 0.35749, saving model to ./dataset1_transformer_results/transformer_model
# 9/9 [==============================] - 1s 83ms/step - loss: 0.4002 - sparse_categorical_accuracy: 0.8184 - val_loss: 0.3575 - val_sparse_categorical_accuracy: 0.8483
# Epoch 37/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.4127 - sparse_categorical_accuracy: 0.8047
# Epoch 37: val_loss improved from 0.35749 to 0.35644, saving model to ./dataset1_transformer_results/transformer_model
# 9/9 [==============================] - 1s 85ms/step - loss: 0.4099 - sparse_categorical_accuracy: 0.8052 - val_loss: 0.3564 - val_sparse_categorical_accuracy: 0.8539
# Epoch 38/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.3606 - sparse_categorical_accuracy: 0.8457
# Epoch 38: val_loss improved from 0.35644 to 0.35288, saving model to ./dataset1_transformer_results/transformer_model
# 9/9 [==============================] - 1s 84ms/step - loss: 0.3586 - sparse_categorical_accuracy: 0.8446 - val_loss: 0.3529 - val_sparse_categorical_accuracy: 0.8483
# Epoch 39/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.4058 - sparse_categorical_accuracy: 0.8145
# Epoch 39: val_loss did not improve from 0.35288
# 9/9 [==============================] - 1s 64ms/step - loss: 0.4033 - sparse_categorical_accuracy: 0.8146 - val_loss: 0.3666 - val_sparse_categorical_accuracy: 0.8371
# Epoch 40/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.3663 - sparse_categorical_accuracy: 0.8477
# Epoch 40: val_loss did not improve from 0.35288
# 9/9 [==============================] - 1s 63ms/step - loss: 0.3641 - sparse_categorical_accuracy: 0.8502 - val_loss: 0.3665 - val_sparse_categorical_accuracy: 0.8427
# Epoch 41/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.3966 - sparse_categorical_accuracy: 0.8008
# Epoch 41: val_loss improved from 0.35288 to 0.34675, saving model to ./dataset1_transformer_results/transformer_model
# 9/9 [==============================] - 1s 89ms/step - loss: 0.3944 - sparse_categorical_accuracy: 0.8034 - val_loss: 0.3468 - val_sparse_categorical_accuracy: 0.8652
# Epoch 42/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.4124 - sparse_categorical_accuracy: 0.8008
# Epoch 42: val_loss did not improve from 0.34675
# 9/9 [==============================] - 1s 63ms/step - loss: 0.4100 - sparse_categorical_accuracy: 0.8015 - val_loss: 0.3677 - val_sparse_categorical_accuracy: 0.8539
# Epoch 43/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.3521 - sparse_categorical_accuracy: 0.8184
# Epoch 43: val_loss improved from 0.34675 to 0.34505, saving model to ./dataset1_transformer_results/transformer_model
# 9/9 [==============================] - 1s 85ms/step - loss: 0.3536 - sparse_categorical_accuracy: 0.8165 - val_loss: 0.3451 - val_sparse_categorical_accuracy: 0.8708
# Epoch 44/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.3668 - sparse_categorical_accuracy: 0.8320
# Epoch 44: val_loss improved from 0.34505 to 0.33894, saving model to ./dataset1_transformer_results/transformer_model
# 9/9 [==============================] - 1s 88ms/step - loss: 0.3707 - sparse_categorical_accuracy: 0.8296 - val_loss: 0.3389 - val_sparse_categorical_accuracy: 0.8652
# Epoch 45/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.3460 - sparse_categorical_accuracy: 0.8457
# Epoch 45: val_loss improved from 0.33894 to 0.32745, saving model to ./dataset1_transformer_results/transformer_model
# 9/9 [==============================] - 1s 86ms/step - loss: 0.3482 - sparse_categorical_accuracy: 0.8408 - val_loss: 0.3275 - val_sparse_categorical_accuracy: 0.8708
# Epoch 46/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.3455 - sparse_categorical_accuracy: 0.8438
# Epoch 46: val_loss did not improve from 0.32745
# 9/9 [==============================] - 1s 61ms/step - loss: 0.3517 - sparse_categorical_accuracy: 0.8408 - val_loss: 0.3287 - val_sparse_categorical_accuracy: 0.8764
# Epoch 47/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.3475 - sparse_categorical_accuracy: 0.8438
# Epoch 47: val_loss improved from 0.32745 to 0.32227, saving model to ./dataset1_transformer_results/transformer_model
# 9/9 [==============================] - 1s 92ms/step - loss: 0.3434 - sparse_categorical_accuracy: 0.8502 - val_loss: 0.3223 - val_sparse_categorical_accuracy: 0.8820
# Epoch 48/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.3660 - sparse_categorical_accuracy: 0.8281
# Epoch 48: val_loss did not improve from 0.32227
# 9/9 [==============================] - 1s 64ms/step - loss: 0.3604 - sparse_categorical_accuracy: 0.8315 - val_loss: 0.3267 - val_sparse_categorical_accuracy: 0.8764
# Epoch 49/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.3428 - sparse_categorical_accuracy: 0.8398
# Epoch 49: val_loss improved from 0.32227 to 0.31758, saving model to ./dataset1_transformer_results/transformer_model
# 9/9 [==============================] - 1s 94ms/step - loss: 0.3418 - sparse_categorical_accuracy: 0.8390 - val_loss: 0.3176 - val_sparse_categorical_accuracy: 0.8764
# Epoch 50/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.3696 - sparse_categorical_accuracy: 0.8301
# Epoch 50: val_loss did not improve from 0.31758
# 9/9 [==============================] - 1s 65ms/step - loss: 0.3715 - sparse_categorical_accuracy: 0.8296 - val_loss: 0.3218 - val_sparse_categorical_accuracy: 0.8764
# Epoch 51/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.3899 - sparse_categorical_accuracy: 0.8340
# Epoch 51: val_loss improved from 0.31758 to 0.31377, saving model to ./dataset1_transformer_results/transformer_model
# 9/9 [==============================] - 1s 93ms/step - loss: 0.3886 - sparse_categorical_accuracy: 0.8333 - val_loss: 0.3138 - val_sparse_categorical_accuracy: 0.8764
# Epoch 52/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.3448 - sparse_categorical_accuracy: 0.8535
# Epoch 52: val_loss improved from 0.31377 to 0.31363, saving model to ./dataset1_transformer_results/transformer_model
# 9/9 [==============================] - 1s 96ms/step - loss: 0.3421 - sparse_categorical_accuracy: 0.8558 - val_loss: 0.3136 - val_sparse_categorical_accuracy: 0.8820
# Epoch 53/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.3464 - sparse_categorical_accuracy: 0.8379
# Epoch 53: val_loss did not improve from 0.31363
# 9/9 [==============================] - 1s 64ms/step - loss: 0.3511 - sparse_categorical_accuracy: 0.8352 - val_loss: 0.3204 - val_sparse_categorical_accuracy: 0.8876
# Epoch 54/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.3616 - sparse_categorical_accuracy: 0.8457
# Epoch 54: val_loss did not improve from 0.31363
# 9/9 [==============================] - 1s 63ms/step - loss: 0.3653 - sparse_categorical_accuracy: 0.8446 - val_loss: 0.3191 - val_sparse_categorical_accuracy: 0.8820
# Epoch 55/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.3391 - sparse_categorical_accuracy: 0.8457
# Epoch 55: val_loss did not improve from 0.31363
# 9/9 [==============================] - 1s 62ms/step - loss: 0.3384 - sparse_categorical_accuracy: 0.8427 - val_loss: 0.3312 - val_sparse_categorical_accuracy: 0.8708
# Epoch 56/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.3625 - sparse_categorical_accuracy: 0.8477
# Epoch 56: val_loss did not improve from 0.31363
# 9/9 [==============================] - 1s 61ms/step - loss: 0.3608 - sparse_categorical_accuracy: 0.8483 - val_loss: 0.3188 - val_sparse_categorical_accuracy: 0.8764
# Epoch 57/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.3546 - sparse_categorical_accuracy: 0.8477
# Epoch 57: val_loss did not improve from 0.31363
# 9/9 [==============================] - 1s 61ms/step - loss: 0.3576 - sparse_categorical_accuracy: 0.8446 - val_loss: 0.3211 - val_sparse_categorical_accuracy: 0.8764
# Epoch 58/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.3561 - sparse_categorical_accuracy: 0.8555
# Epoch 58: val_loss did not improve from 0.31363
# 9/9 [==============================] - 1s 62ms/step - loss: 0.3650 - sparse_categorical_accuracy: 0.8539 - val_loss: 0.3209 - val_sparse_categorical_accuracy: 0.8820
# Epoch 59/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.3589 - sparse_categorical_accuracy: 0.8262
# Epoch 59: val_loss did not improve from 0.31363
# 9/9 [==============================] - 1s 62ms/step - loss: 0.3545 - sparse_categorical_accuracy: 0.8258 - val_loss: 0.3150 - val_sparse_categorical_accuracy: 0.8820
# Epoch 60/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.3626 - sparse_categorical_accuracy: 0.8418
# Epoch 60: val_loss did not improve from 0.31363
# 9/9 [==============================] - 1s 64ms/step - loss: 0.3676 - sparse_categorical_accuracy: 0.8408 - val_loss: 0.3237 - val_sparse_categorical_accuracy: 0.8764
# Epoch 61/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.3191 - sparse_categorical_accuracy: 0.8535
# Epoch 61: val_loss improved from 0.31363 to 0.30606, saving model to ./dataset1_transformer_results/transformer_model
# 9/9 [==============================] - 1s 85ms/step - loss: 0.3257 - sparse_categorical_accuracy: 0.8502 - val_loss: 0.3061 - val_sparse_categorical_accuracy: 0.8764
# Epoch 62/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.3364 - sparse_categorical_accuracy: 0.8457
# Epoch 62: val_loss improved from 0.30606 to 0.30438, saving model to ./dataset1_transformer_results/transformer_model
# 9/9 [==============================] - 1s 84ms/step - loss: 0.3352 - sparse_categorical_accuracy: 0.8483 - val_loss: 0.3044 - val_sparse_categorical_accuracy: 0.8652
# Epoch 63/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.3236 - sparse_categorical_accuracy: 0.8613
# Epoch 63: val_loss improved from 0.30438 to 0.30110, saving model to ./dataset1_transformer_results/transformer_model
# 9/9 [==============================] - 1s 81ms/step - loss: 0.3273 - sparse_categorical_accuracy: 0.8596 - val_loss: 0.3011 - val_sparse_categorical_accuracy: 0.8708
# Epoch 64/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.3534 - sparse_categorical_accuracy: 0.8379
# Epoch 64: val_loss improved from 0.30110 to 0.29409, saving model to ./dataset1_transformer_results/transformer_model
# 9/9 [==============================] - 1s 86ms/step - loss: 0.3549 - sparse_categorical_accuracy: 0.8371 - val_loss: 0.2941 - val_sparse_categorical_accuracy: 0.8764
# Epoch 65/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.3431 - sparse_categorical_accuracy: 0.8418
# Epoch 65: val_loss improved from 0.29409 to 0.28849, saving model to ./dataset1_transformer_results/transformer_model
# 9/9 [==============================] - 1s 85ms/step - loss: 0.3423 - sparse_categorical_accuracy: 0.8408 - val_loss: 0.2885 - val_sparse_categorical_accuracy: 0.8764
# Epoch 66/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.3269 - sparse_categorical_accuracy: 0.8555
# Epoch 66: val_loss did not improve from 0.28849
# 9/9 [==============================] - 1s 63ms/step - loss: 0.3203 - sparse_categorical_accuracy: 0.8596 - val_loss: 0.2927 - val_sparse_categorical_accuracy: 0.8820
# Epoch 67/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.3615 - sparse_categorical_accuracy: 0.8301
# Epoch 67: val_loss did not improve from 0.28849
# 9/9 [==============================] - 1s 65ms/step - loss: 0.3601 - sparse_categorical_accuracy: 0.8315 - val_loss: 0.2905 - val_sparse_categorical_accuracy: 0.8764
# Epoch 68/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.3444 - sparse_categorical_accuracy: 0.8496
# Epoch 68: val_loss did not improve from 0.28849
# 9/9 [==============================] - 1s 62ms/step - loss: 0.3489 - sparse_categorical_accuracy: 0.8464 - val_loss: 0.2965 - val_sparse_categorical_accuracy: 0.8933
# Epoch 69/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.3424 - sparse_categorical_accuracy: 0.8379
# Epoch 69: val_loss did not improve from 0.28849
# 9/9 [==============================] - 1s 62ms/step - loss: 0.3416 - sparse_categorical_accuracy: 0.8371 - val_loss: 0.3090 - val_sparse_categorical_accuracy: 0.8539
# Epoch 70/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.3567 - sparse_categorical_accuracy: 0.8262
# Epoch 70: val_loss did not improve from 0.28849
# 9/9 [==============================] - 1s 61ms/step - loss: 0.3508 - sparse_categorical_accuracy: 0.8315 - val_loss: 0.2918 - val_sparse_categorical_accuracy: 0.8876
# Epoch 71/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.3265 - sparse_categorical_accuracy: 0.8496
# Epoch 71: val_loss improved from 0.28849 to 0.28165, saving model to ./dataset1_transformer_results/transformer_model
# 9/9 [==============================] - 1s 87ms/step - loss: 0.3243 - sparse_categorical_accuracy: 0.8521 - val_loss: 0.2817 - val_sparse_categorical_accuracy: 0.8876
# Epoch 72/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.3000 - sparse_categorical_accuracy: 0.8516
# Epoch 72: val_loss improved from 0.28165 to 0.27880, saving model to ./dataset1_transformer_results/transformer_model
# 9/9 [==============================] - 1s 83ms/step - loss: 0.3103 - sparse_categorical_accuracy: 0.8446 - val_loss: 0.2788 - val_sparse_categorical_accuracy: 0.8876
# Epoch 73/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.3070 - sparse_categorical_accuracy: 0.8848
# Epoch 73: val_loss did not improve from 0.27880
# 9/9 [==============================] - 1s 64ms/step - loss: 0.3075 - sparse_categorical_accuracy: 0.8820 - val_loss: 0.2796 - val_sparse_categorical_accuracy: 0.8820
# Epoch 74/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.3427 - sparse_categorical_accuracy: 0.8652
# Epoch 74: val_loss improved from 0.27880 to 0.27871, saving model to ./dataset1_transformer_results/transformer_model
# 9/9 [==============================] - 1s 93ms/step - loss: 0.3415 - sparse_categorical_accuracy: 0.8652 - val_loss: 0.2787 - val_sparse_categorical_accuracy: 0.8989
# Epoch 75/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.2903 - sparse_categorical_accuracy: 0.8691
# Epoch 75: val_loss did not improve from 0.27871
# 9/9 [==============================] - 1s 66ms/step - loss: 0.2895 - sparse_categorical_accuracy: 0.8689 - val_loss: 0.2788 - val_sparse_categorical_accuracy: 0.8933
# Epoch 76/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.3077 - sparse_categorical_accuracy: 0.8672
# Epoch 76: val_loss did not improve from 0.27871
# 9/9 [==============================] - 1s 63ms/step - loss: 0.3084 - sparse_categorical_accuracy: 0.8652 - val_loss: 0.2820 - val_sparse_categorical_accuracy: 0.8764
# Epoch 77/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.3214 - sparse_categorical_accuracy: 0.8691
# Epoch 77: val_loss did not improve from 0.27871
# 9/9 [==============================] - 1s 62ms/step - loss: 0.3213 - sparse_categorical_accuracy: 0.8727 - val_loss: 0.2812 - val_sparse_categorical_accuracy: 0.8876
# Epoch 78/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.3141 - sparse_categorical_accuracy: 0.8594
# Epoch 78: val_loss improved from 0.27871 to 0.27483, saving model to ./dataset1_transformer_results/transformer_model
# 9/9 [==============================] - 1s 86ms/step - loss: 0.3084 - sparse_categorical_accuracy: 0.8614 - val_loss: 0.2748 - val_sparse_categorical_accuracy: 0.8933
# Epoch 79/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.2901 - sparse_categorical_accuracy: 0.8750
# Epoch 79: val_loss did not improve from 0.27483
# 9/9 [==============================] - 1s 61ms/step - loss: 0.2969 - sparse_categorical_accuracy: 0.8689 - val_loss: 0.2798 - val_sparse_categorical_accuracy: 0.8933
# Epoch 80/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.3054 - sparse_categorical_accuracy: 0.8730
# Epoch 80: val_loss did not improve from 0.27483
# 9/9 [==============================] - 1s 64ms/step - loss: 0.3132 - sparse_categorical_accuracy: 0.8670 - val_loss: 0.2801 - val_sparse_categorical_accuracy: 0.8876
# Epoch 81/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.3228 - sparse_categorical_accuracy: 0.8516
# Epoch 81: val_loss did not improve from 0.27483
# 9/9 [==============================] - 1s 62ms/step - loss: 0.3192 - sparse_categorical_accuracy: 0.8539 - val_loss: 0.2780 - val_sparse_categorical_accuracy: 0.8933
# Epoch 82/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.3133 - sparse_categorical_accuracy: 0.8770
# Epoch 82: val_loss improved from 0.27483 to 0.27350, saving model to ./dataset1_transformer_results/transformer_model
# 9/9 [==============================] - 1s 85ms/step - loss: 0.3157 - sparse_categorical_accuracy: 0.8727 - val_loss: 0.2735 - val_sparse_categorical_accuracy: 0.8933
# Epoch 83/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.3024 - sparse_categorical_accuracy: 0.8711
# Epoch 83: val_loss improved from 0.27350 to 0.27193, saving model to ./dataset1_transformer_results/transformer_model
# 9/9 [==============================] - 1s 84ms/step - loss: 0.3049 - sparse_categorical_accuracy: 0.8708 - val_loss: 0.2719 - val_sparse_categorical_accuracy: 0.8933
# Epoch 84/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.3161 - sparse_categorical_accuracy: 0.8613
# Epoch 84: val_loss did not improve from 0.27193
# 9/9 [==============================] - 1s 61ms/step - loss: 0.3102 - sparse_categorical_accuracy: 0.8670 - val_loss: 0.2740 - val_sparse_categorical_accuracy: 0.8933
# Epoch 85/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.3078 - sparse_categorical_accuracy: 0.8594
# Epoch 85: val_loss did not improve from 0.27193
# 9/9 [==============================] - 1s 62ms/step - loss: 0.3105 - sparse_categorical_accuracy: 0.8577 - val_loss: 0.2728 - val_sparse_categorical_accuracy: 0.8933
# Epoch 86/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.3044 - sparse_categorical_accuracy: 0.8613
# Epoch 86: val_loss did not improve from 0.27193
# 9/9 [==============================] - 1s 68ms/step - loss: 0.2976 - sparse_categorical_accuracy: 0.8670 - val_loss: 0.2754 - val_sparse_categorical_accuracy: 0.8933
# Epoch 87/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.2955 - sparse_categorical_accuracy: 0.8730
# Epoch 87: val_loss improved from 0.27193 to 0.26549, saving model to ./dataset1_transformer_results/transformer_model
# 9/9 [==============================] - 1s 93ms/step - loss: 0.2968 - sparse_categorical_accuracy: 0.8727 - val_loss: 0.2655 - val_sparse_categorical_accuracy: 0.9045
# Epoch 88/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.3075 - sparse_categorical_accuracy: 0.8691
# Epoch 88: val_loss improved from 0.26549 to 0.26282, saving model to ./dataset1_transformer_results/transformer_model
# 9/9 [==============================] - 1s 87ms/step - loss: 0.3132 - sparse_categorical_accuracy: 0.8652 - val_loss: 0.2628 - val_sparse_categorical_accuracy: 0.8989
# Epoch 89/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.3225 - sparse_categorical_accuracy: 0.8555
# Epoch 89: val_loss improved from 0.26282 to 0.26112, saving model to ./dataset1_transformer_results/transformer_model
# 9/9 [==============================] - 1s 86ms/step - loss: 0.3191 - sparse_categorical_accuracy: 0.8596 - val_loss: 0.2611 - val_sparse_categorical_accuracy: 0.9045
# Epoch 90/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.2835 - sparse_categorical_accuracy: 0.8809
# Epoch 90: val_loss did not improve from 0.26112
# ...
# Epoch 448/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.2317 - sparse_categorical_accuracy: 0.9082
# Epoch 448: val_loss did not improve from 0.18296
# 9/9 [==============================] - 1s 66ms/step - loss: 0.2294 - sparse_categorical_accuracy: 0.9082 - val_loss: 0.2328 - val_sparse_categorical_accuracy: 0.9438
# Epoch 449/10000
# 9/9 [==============================] - ETA: 0s - loss: 0.2426 - sparse_categorical_accuracy: 0.8914
# Epoch 449: val_loss did not improve from 0.18296
# 9/9 [==============================] - 1s 91ms/step - loss: 0.2426 - sparse_categorical_accuracy: 0.8914 - val_loss: 0.2281 - val_sparse_categorical_accuracy: 0.9494
# Epoch 450/10000
# 9/9 [==============================] - ETA: 0s - loss: 0.2266 - sparse_categorical_accuracy: 0.9139
# Epoch 450: val_loss did not improve from 0.18296
# 9/9 [==============================] - 1s
10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.2382 - sparse_categorical_accuracy: 0.9102
# Epoch 489: val_loss did not improve from 0.18296
# 9/9 [==============================] - 1s 65ms/step - loss: 0.2349 - sparse_categorical_accuracy: 0.9120 - val_loss: 0.2186 - val_sparse_categorical_accuracy: 0.9551
# Epoch 490/10000
# 9/9 [==============================] - ETA: 0s - loss: 0.2127 - sparse_categorical_accuracy: 0.9120
# Epoch 490: val_loss did not improve from 0.18296
# 9/9 [==============================] - 1s 94ms/step - loss: 0.2127 - sparse_categorical_accuracy: 0.9120 - val_loss: 0.2174 - val_sparse_categorical_accuracy: 0.9551
# Epoch 491/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.1975 - sparse_categorical_accuracy: 0.9180
# Epoch 491: val_loss did not improve from 0.18296
# 9/9 [==============================] - 1s 76ms/step - loss: 0.1969 - sparse_categorical_accuracy: 0.9195 - val_loss: 0.2040 - val_sparse_categorical_accuracy: 0.9551
# Epoch 492/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.2414 - sparse_categorical_accuracy: 0.9062
# Epoch 492: val_loss did not improve from 0.18296
# 9/9 [==============================] - 1s 64ms/step - loss: 0.2551 - sparse_categorical_accuracy: 0.9007 - val_loss: 0.2066 - val_sparse_categorical_accuracy: 0.9213
# Epoch 493/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.1832 - sparse_categorical_accuracy: 0.9141
# Epoch 493: val_loss did not improve from 0.18296
# 9/9 [==============================] - 1s 62ms/step - loss: 0.1896 - sparse_categorical_accuracy: 0.9101 - val_loss: 0.1899 - val_sparse_categorical_accuracy: 0.9494
# Epoch 494/10000
# 8/9 [=========================>....] - ETA: 0s - loss: 0.2205 - sparse_categorical_accuracy: 0.9082
# Epoch 494: val_loss did not improve from 0.18296
# 9/9 [==============================] - 1s 67ms/step - loss: 0.2268 - sparse_categorical_accuracy: 0.9045 - val_loss: 0.2007 - val_sparse_categorical_accuracy: 0.9438
# 6/6 [==============================] - 0s 23ms/step - loss: 0.1830 - sparse_categorical_accuracy: 0.9270
# 0.18295884132385254 0.9269663095474243
# 6/6 [==============================] - 0s 13ms/step - loss: 0.3268 - sparse_categorical_accuracy: 0.8989
# 0.3268318772315979 0.898876428604126

# %%
plot_accuracy_comparison([results.history["sparse_categorical_accuracy"], results.history["val_sparse_categorical_accuracy"]],
                        "Training/Validation Accuracy Comparison",
                        ["Training Accuracy", "Validation Accuracy"],
                        save_path = "./dataset1_transformer_results/transformer_dataset1_acc_comparison.svg")

# %%
plot_loss_comparison([results.history["loss"], results.history["val_loss"]],
                     "Training/Validation Loss Comparison",
                     ["Training Loss", "Validation Loss"],
                     save_path = "./dataset1_transformer_results/transformer_dataset1_loss_comparison.svg")

# %%
y_pred=np.argmax(model.predict(x_test), axis=-1)
print(classification_report(y_pred,y_test, digits=4))
plot_confusion_matrix(y_test, y_pred, ["bottle", "cube", "long_block"],
                      save_path = "./dataset1_transformer_results/transformer_dataset1_conf_matrix.svg")

write_results(results.history['sparse_categorical_accuracy'][-200], a, A,
              results.history['loss'][-200], l, L,
              classification_report(y_pred,y_test, digits=4),
              save_path = "./dataset1_transformer_results/transformer_dataset1_results.txt")
# Out:
# 6/6 [==============================] - 1s 11ms/step
#               precision    recall  f1-score   support
#
#            0     0.9667    0.9831    0.9748        59
#            1     0.9831    0.7945    0.8788        73
#            2     0.7458    0.9565    0.8381        46
#
#     accuracy                         0.8989       178
#    macro avg     0.8985    0.9114    0.8972       178
# weighted avg     0.9163    0.8989    0.9001       178
